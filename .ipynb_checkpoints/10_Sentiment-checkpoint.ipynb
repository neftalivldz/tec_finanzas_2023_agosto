# %%
#!pip3 install textblob

# %%
import eikon as ek
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from textblob import TextBlob
import datetime
from datetime import time
import warnings
warnings.filterwarnings("ignore")
import configparser as cp
#https://github.com/Refinitiv-API-Samples/Article.EikonAPI.Python.NewsSentimentAnalysis

# %% [markdown]
# Basado en el siguiente artículo:
#
# jasonramchandani
# @rsamasiri rsamasiri Raksina Samasiri
#
# #https://github.com/Refinitiv-API-Samples/Article.EikonAPI.Python.NewsSentimentAnalysis

# %%
cfg = cp.ConfigParser()
cfg.read('../refinitiv.cfg')
ek.set_app_key(cfg['eikon']['app_id'])

# %%
import pandas as pd
pd.merge
# Out:
# <function pandas.core.reshape.merge.merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | None' = None, left_on: 'IndexLabel | None' = None, right_on: 'IndexLabel | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'>

# %%
from datetime import datetime, timedelta
end = datetime.today()
start = end - timedelta(days=(365.2*4))
print(start, end)
# Out:
# 2019-10-03 20:30:56.396580 2023-10-03 15:42:56.396580

# %%
df = ek.get_news_headlines('R:MSFT.O AND Language:LEN', date_from=start, date_to=end, count=100)
df.head()
# Out:
#                                           versionCreated
# 2023-10-03 15:28:56.268 2023-10-03 15:34:13.969000+00:00  \
# 2023-10-03 10:26:14.160 2023-10-03 15:30:28.389000+00:00
# 2023-10-03 15:29:31.000        2023-10-03 15:29:31+00:00
# 2023-10-03 14:48:08.949 2023-10-03 15:08:15.524000+00:00
# 2023-10-03 15:00:00.504 2023-10-03 15:00:00.504000+00:00
#
#                                                                       text
# 2023-10-03 15:28:56.268              REG - Bango PLC - Total Voting Rights  \
# 2023-10-03 10:26:14.160        REG - Allianz Global Invs - Top 10 Holdings
# 2023-10-03 15:29:31.000  BUZZ-Amazon, Microsoft fall as UK regulator pu...
# 2023-10-03 14:48:08.949  REG - Haydale Graphene Ind - Result of General...
# 2023-10-03 15:00:00.504  ELEVATE SECURITY INTRODUCES ADAPTIVE TRUST, UN...
#
#                                                                    storyId
# 2023-10-03 15:28:56.268  urn:newsml:newsroom.refinitiv.com:20231003:nRS...  \
# 2023-10-03 10:26:14.160  urn:newsml:newsroom.refinitiv.com:20231003:nRS...
# 2023-10-03 15:29:31.000  urn:newsml:newswire.refinitiv.com:20231003:nL4...
# 2023-10-03 14:48:08.949  urn:newsml:newsroom.refinitiv.com:20231003:nRS...
# 2023-10-03 15:00:00.504  urn:newsml:newswire.refinitiv.com:20231003:nTU...
#
#                         sourceCode
# 2023-10-03 15:28:56.268     NS:LSE
# 2023-10-03 10:26:14.160     NS:LSE
# 2023-10-03 15:29:31.000    NS:RTRS
# 2023-10-03 14:48:08.949     NS:LSE
# 2023-10-03 15:00:00.504    NS:RTRS

# %%
df['Polarity'] = np.nan
df['Subjectivity'] = np.nan
df['Score'] = np.nan

# %%
#for idx, storyId in enumerate(df['storyId'].values):  #for each row in our df dataframe
#    print(idx, storyId)
#    newsText = ek.get_news_story(storyId) #get the news story
#    print(newsText)

# %%
for idx, storyId in enumerate(df['storyId'].values):  #for each row in our df dataframe
    newsText = ek.get_news_story(storyId) #get the news story
    if newsText:
        soup = BeautifulSoup(newsText,"lxml") #create a BeautifulSoup object from our HTML news article
        sentA = TextBlob(soup.get_text()) #pass the text only article to TextBlob to anaylse
        df['Polarity'].iloc[idx] = sentA.sentiment.polarity #write sentiment polarity back to df
        df['Subjectivity'].iloc[idx] = sentA.sentiment.subjectivity #write sentiment subjectivity score back to df
        if sentA.sentiment.polarity >= 0.05: # attribute bucket to sentiment polartiy
            score = 'positive'
        elif  -.05 < sentA.sentiment.polarity < 0.05:
            score = 'neutral'
        else:
            score = 'negative'
        df['Score'].iloc[idx] = score #write score back to df
df.head()
# Out:
#                                           versionCreated
# 2023-10-03 15:28:56.268 2023-10-03 15:34:13.969000+00:00  \
# 2023-10-03 10:26:14.160 2023-10-03 15:30:28.389000+00:00
# 2023-10-03 15:29:31.000        2023-10-03 15:29:31+00:00
# 2023-10-03 14:48:08.949 2023-10-03 15:08:15.524000+00:00
# 2023-10-03 15:00:00.504 2023-10-03 15:00:00.504000+00:00
#
#                                                                       text
# 2023-10-03 15:28:56.268              REG - Bango PLC - Total Voting Rights  \
# 2023-10-03 10:26:14.160        REG - Allianz Global Invs - Top 10 Holdings
# 2023-10-03 15:29:31.000  BUZZ-Amazon, Microsoft fall as UK regulator pu...
# 2023-10-03 14:48:08.949  REG - Haydale Graphene Ind - Result of General...
# 2023-10-03 15:00:00.504  ELEVATE SECURITY INTRODUCES ADAPTIVE TRUST, UN...
#
#                                                                    storyId
# 2023-10-03 15:28:56.268  urn:newsml:newsroom.refinitiv.com:20231003:nRS...  \
# 2023-10-03 10:26:14.160  urn:newsml:newsroom.refinitiv.com:20231003:nRS...
# 2023-10-03 15:29:31.000  urn:newsml:newswire.refinitiv.com:20231003:nL4...
# 2023-10-03 14:48:08.949  urn:newsml:newsroom.refinitiv.com:20231003:nRS...
# 2023-10-03 15:00:00.504  urn:newsml:newswire.refinitiv.com:20231003:nTU...
#
#                         sourceCode  Polarity  Subjectivity     Score
# 2023-10-03 15:28:56.268     NS:LSE  0.091901      0.397221  positive
# 2023-10-03 10:26:14.160     NS:LSE  0.115646      0.342517  positive
# 2023-10-03 15:29:31.000    NS:RTRS  0.048990      0.407071   neutral
# 2023-10-03 14:48:08.949     NS:LSE  0.015422      0.353602   neutral
# 2023-10-03 15:00:00.504    NS:RTRS  0.000000      0.000000   neutral

# %%
start = df['versionCreated'].min().replace(hour=0,minute=0,second=0,microsecond=0).strftime('%Y/%m/%d')
end = df['versionCreated'].max().replace(hour=0,minute=0,second=0,microsecond=0).strftime('%Y/%m/%d')
Minute = ek.get_timeseries(["MSFT.O"], start_date=start, interval="minute")
Minute
# Out:
# MSFT.O                 HIGH     LOW    OPEN   CLOSE  COUNT  VOLUME
# Date
# 2023-09-29 00:00:00   314.2  313.72  314.12  313.72     48     268
# 2023-09-29 08:01:00  315.99  314.99  315.99   315.6     17     489
# 2023-09-29 08:02:00  315.56  315.35  315.56  315.35      9     120
# 2023-09-29 08:03:00  315.55  315.49  315.51  315.54     19     573
# 2023-09-29 08:04:00   315.6  315.39   315.5   315.6     18     558
# 61 2023-10-02T11:11:08.000000000
# 62 2023-10-02T10:06:01.000000000
# 63 2023-10-02T07:22:06.815000000
# 64 2023-10-02T06:05:45.743000000
# 65 2023-10-02T05:16:13.090000000
# 66 2023-10-02T03:03:40.240000000
# 67 2023-10-02T02:33:16.441000000
# 68 2023-10-02T01:24:11.443000000
# 69 2023-10-02T01:03:26.314000000
# 70 2023-10-02T00:29:48.000000000
# 71 2023-10-01T22:00:43.000000000
# 72 2023-10-01T13:00:00.000000000
# 73 2023-10-01T08:45:35.000000000
# 74 2023-10-01T02:46:14.738000000
# 75 2023-10-01T02:36:06.269000000
# 76 2023-10-01T02:35:37.720000000
# 77 2023-10-01T02:35:27.956000000
# 78 2023-10-01T02:34:56.202000000
# 79 2023-09-30T07:46:18.316000000
# 80 2023-09-30T04:27:05.012000000
# 81 2023-09-30T04:21:48.741000000
# 82 2023-09-30T03:04:08.503000000
# 83 2023-09-30T02:57:31.455000000
# 84 2023-09-30T02:44:14.980000000
# 85 2023-09-30T02:43:25.236000000
# 86 2023-09-30T02:43:24.406000000
# 87 2023-09-30T02:43:02.418000000
# 88 2023-09-30T02:42:34.938000000
# 89 2023-09-30T02:40:51.061000000
# 90 2023-09-30T02:39:57.334000000
# 91 2023-09-30T02:39:53.346000000
# 92 2023-09-30T02:38:21.276000000
# 93 2023-09-29T22:18:05.000000000
# 94 2023-09-29T21:13:13.106000000
# 95 2023-09-29T18:55:16.942000000
# 96 2023-09-29T18:30:27.000000000
# 97 2023-09-29T18:03:49.000000000
# 98 2023-09-29T17:55:56.554000000
# 99 2023-09-29T16:22:57.682000000

# %%
idx = 0
newsDate = '2023-10-03T15:29:31.000000000'
sTime = df['versionCreated'][idx]
sTime = sTime.replace(second=0,microsecond=0)
sTime
# Out:
# Timestamp('2023-10-03 15:34:00+0000', tz='UTC')

# %%
t0 = Minute.iloc[Minute.index.get_loc(sTime),2]
t0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py:532, in DatetimeIndex._disallow_mismatched_indexing(self, key)
#     530 try:
#     531     # GH#36148
# --> 532     self._data._assert_tzawareness_compat(key)
#     533 except TypeError as err:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:744, in DatetimeArray._assert_tzawareness_compat(self, other)
#     743     if other_tz is not None:
# --> 744         raise TypeError(
#     745             "Cannot compare tz-naive and tz-aware datetime-like objects."
#     746         )
#     747 elif other_tz is None:
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects.
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 t0 = Minute.iloc[Minute.index.get_loc(sTime),2]
#       2 t0
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py:552, in DatetimeIndex.get_loc(self, key)
#     548     key = NaT
#     550 if isinstance(key, self._data._recognized_scalars):
#     551     # needed to localize naive datetimes
# --> 552     self._disallow_mismatched_indexing(key)
#     553     key = Timestamp(key)
#     555 elif isinstance(key, str):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py:534, in DatetimeIndex._disallow_mismatched_indexing(self, key)
#     532     self._data._assert_tzawareness_compat(key)
#     533 except TypeError as err:
# --> 534     raise KeyError(key) from err
#
# KeyError: Timestamp('2023-10-03 15:34:00+0000', tz='UTC')

# %%
Minute.iloc[Minute.index.get_loc((sTime + timedelta(minutes=2))),3]
# Out:
# 283.2

# %%
for idx, newsDate in enumerate(df['versionCreated'].values):
    sTime = df['versionCreated'][idx]
    sTime = sTime.replace(second=0,microsecond=0)
    try:
        t0 = Minute.iloc[Minute.index.get_loc(sTime),2]
        df['twoM'][idx] = ((Minute.iloc[Minute.index.get_loc((sTime + timedelta(minutes=2))),3]/(t0)-1)*100)
        df['fiveM'][idx] = ((Minute.iloc[Minute.index.get_loc((sTime + timedelta(minutes=5))),3]/(t0)-1)*100)
        df['tenM'][idx] = ((Minute.iloc[Minute.index.get_loc((sTime + timedelta(minutes=10))),3]/(t0)-1)*100) 
        df['thirtyM'][idx] = ((Minute.iloc[Minute.index.get_loc((sTime + timedelta(minutes=30))),3]/(t0)-1)*100)
    except:
        pass
df.head()
# Out:
#                                           versionCreated  \
# 2023-04-18 07:46:19.000        2023-04-18 17:52:46+00:00
# 2023-04-18 17:44:05.666 2023-04-18 17:44:05.666000+00:00
# 2023-04-18 17:30:54.000        2023-04-18 17:30:54+00:00
# 2023-04-18 17:25:09.000        2023-04-18 17:25:09+00:00
# 2023-04-18 17:22:03.000        2023-04-18 17:22:03+00:00
#
#                                                                       text  \
# 2023-04-18 07:46:19.000  U.S. RESEARCH ROUNDUP-Aterian, Berkshire Hatha...
# 2023-04-18 17:44:05.666  Microsoft (MSFT) Azure Expands Strategic Partn...
# 2023-04-18 17:30:54.000                    LIVE MARKETS-Search and disrupt
# 2023-04-18 17:25:09.000  UN Women - Overcoming gender-based violence as...
# 2023-04-18 17:22:03.000  US FTC leaders will target AI that violates ci...
#
#                                                                    storyId  \
# 2023-04-18 07:46:19.000  urn:newsml:newswire.refinitiv.com:20230418:nL4...
# 2023-04-18 17:44:05.666  urn:newsml:newswire.refinitiv.com:20230418:nNR...
# 2023-04-18 17:30:54.000  urn:newsml:newswire.refinitiv.com:20230418:nL1...
# 2023-04-18 17:25:09.000  urn:newsml:newswire.refinitiv.com:20230418:nND...
# 2023-04-18 17:22:03.000  urn:newsml:newswire.refinitiv.com:20230418:nL1...
#
#                         sourceCode  Polarity  Subjectivity     Score  \
# 2023-04-18 07:46:19.000    NS:RTRS  0.026779      0.066479   neutral
# 2023-04-18 17:44:05.666  NS:ZACKSC  0.116939      0.479778  positive
# 2023-04-18 17:30:54.000    NS:RTRS  0.026409      0.371817   neutral
# 2023-04-18 17:25:09.000    NS:PUBT  0.117577      0.310451  positive
# 2023-04-18 17:22:03.000    NS:RTRS -0.077982      0.649912  negative
#
#                              twoM     fiveM      tenM   thirtyM
# 2023-04-18 07:46:19.000 -0.030055 -0.098416 -0.193609 -0.124624
# 2023-04-18 17:44:05.666  0.044555  0.117982  0.070026 -0.076792
# 2023-04-18 17:30:54.000 -0.052845  0.023541  0.048609 -0.053818
# 2023-04-18 17:25:09.000 -0.027758 -0.089969 -0.045869  0.064189
# 2023-04-18 17:22:03.000  0.072639  0.045139 -0.049375  0.142361

# %%
grouped = df.groupby(['Score']).mean()
grouped
# Out:
#           Polarity  Subjectivity      twoM     fiveM      tenM   thirtyM
# Score
# negative -0.074614      0.318861 -0.042092 -0.040307 -0.066435  0.073719
# neutral   0.003039      0.242634  0.018427  0.048040  0.042721 -0.026442
# positive  0.140777      0.441769  0.013360  0.006920  0.016765 -0.018865
