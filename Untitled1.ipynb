# %%
import eikon as ek  # the Eikon Python wrapper package
import numpy as np  # NumPy
import pandas as pd  # pandas
import cufflinks as cf  # Cufflinks
import configparser as cp
cf.set_config_file(offline=True)  # set the plotting mode to offline
import plotly.express as px
import datetime
import plotly.graph_objects as go
import talib as ta
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cfg = cp.ConfigParser()
cfg.read('../refinitiv.cfg')
ek.set_app_key(cfg['eikon']['app_id'])

# %%
dji = ek.get_data('0#.DJI', fields=['TR.CommonName', 'TR.PriceClose',
                                      'TR.Volume', 'TR.TotalReturnYTD'])[0]

# %%
dji
# Out:
#    Instrument                   Company Common Name  Price Close    Volume
# 0        GS.N               Goldman Sachs Group Inc       325.52    477987  \
# 1       NKE.N                              Nike Inc        97.67   1718036
# 2     CSCO.OQ                     Cisco Systems Inc        56.67   5276417
# 3       JPM.N                   JPMorgan Chase & Co       143.83   1822523
# 4       DIS.N                        Walt Disney Co        81.58   3044912
# 5     INTC.OQ                            Intel Corp        38.01  12470347
# 6       DOW.N                               Dow Inc        53.71   1186185
# 7       MRK.N                        Merck & Co Inc       109.05   2107368
# 8       CVX.N                          Chevron Corp       167.21   1968644
# 9       AXP.N                   American Express Co       157.43    473635
# 10       VZ.N            Verizon Communications Inc        33.45   5350618
# ...

# %%
start_date = '2020-01-01'  # Specify the start date
end_date = '2023-09-01'    # Specify the end date

df = ek.get_data('ARTQX.O',['TR.ClosePrice', 'TR.FundNAV.Date', 'TR.FundNAV'], {'SDate':'2012-01-01', 'EDate':'2019-05-26', 'Curn':'Native'})
df
# Out:
# (     Instrument  Close Price                  Date    NAV
#  0       ARTQX.O         <NA>  2012-01-02T00:00:00Z   19.7
#  1       ARTQX.O         <NA>  2012-01-03T00:00:00Z   19.9
#  2       ARTQX.O         <NA>  2012-01-04T00:00:00Z  19.83
#  3       ARTQX.O         <NA>  2012-01-05T00:00:00Z  19.86
#  4       ARTQX.O         <NA>  2012-01-06T00:00:00Z  19.82
#  ...         ...          ...                   ...    ...
#  1925    ARTQX.O         <NA>  2019-05-20T00:00:00Z  19.25
#  1926    ARTQX.O         <NA>  2019-05-21T00:00:00Z  19.49
#  1927    ARTQX.O         <NA>  2019-05-22T00:00:00Z  19.34
#  1928    ARTQX.O         <NA>  2019-05-23T00:00:00Z  19.01
#  1929    ARTQX.O         <NA>  2019-05-24T00:00:00Z  19.05
#
#  [1930 rows x 4 columns],
#  None)

# %%
df['SMA_30'] = ta.SMA(df.NAV, timeperiod=30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['SMA_30'] = ta.SMA(df.NAV, timeperiod=30)
#
# AttributeError: 'tuple' object has no attribute 'NAV'

# %%
type(df)
# Out:
# tuple
