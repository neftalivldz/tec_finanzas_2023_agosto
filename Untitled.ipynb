# %%
# !conda install -y dask distributed
# Out:
# ...
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# ...
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::urllib3==1.26.15=pyhd8ed1ab_0
#   - conda-forge/noarch::google-auth-oauthlib==0.4.6=pyhd8ed1ab_0
#   - conda-forge/noarch::patsy==0.5.3=pyhd8ed1ab_0
#   - conda-forge/noarch::altair==5.0.1=pyhd8ed1ab_1
#   - conda-forge/noarch::formulaic==0.6.1=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::pandas==2.0.1=py38hefb543e_1
#   - conda-forge/osx-arm64::pytorch==2.0.0=cpu_py38hb5ed39e_0
#   - conda-forge/osx-arm64::h5py==3.8.0=nompi_py38hd3ff8df_101
#   - conda-forge/noarch::pyhdfe==0.1.1=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::tensorflow==2.11.1=cpu_py38h970ee7d_0
# ...

# %%
from dask.distributed import Client

# %%
client = Client ()
client
# Out:
# 2023-08-25 13:39:57,574 - distributed.worker - WARNING - Mismatched versions found
#
# +---------+---------------------------------------------+-----------+---------+
# | Package | Worker-378eb82b-663c-48f6-8005-2f9bcbce2ca7 | Scheduler | Workers |
# +---------+---------------------------------------------+-----------+---------+
# | tornado | 6.3.3                                       | 6.2       | 6.3.3   |
# +---------+---------------------------------------------+-----------+---------+
# 2023-08-25 13:39:57,575 - distributed.worker - WARNING - Mismatched versions found
#
# +---------+---------------------------------------------+-----------+---------+
# | Package | Worker-a620c8ef-cc12-44ed-907f-abb62e209bf5 | Scheduler | Workers |
# +---------+---------------------------------------------+-----------+---------+
# | tornado | 6.3.3                                       | 6.2       | 6.3.3   |
# +---------+---------------------------------------------+-----------+---------+
# ...
